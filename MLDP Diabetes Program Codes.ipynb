# %% [markdown]
# # Declaration of Originality

# %% [markdown]
# **School of Informatics & IT**
# <br/>**Diploma in Applied Artificial Intelligence**
# <br/>**Machine Learning for Developers (CAI2C08)**
# <br/>**AY2026/2027 April Semester**
# <br/>**Program Codes**
#
# * Student Name: Skye Tan Ge Hui

# %% [markdown]
# **Declaration of Originality**
# * I am the originator of this work, and I have appropriately acknowledged all other original sources used as my references for this work.
# * I understand that Plagiarism is the act of taking and using the whole or any part of another person’s work, including work generated by AI, and presenting it as my own.
# * I understand that Plagiarism is an academic offence and if I am found to have committed or abetted the offence of plagiarism in relation to this submitted work, disciplinary action will be enforced.

# %% [markdown]
# # Libraries

# %%
# Import libraries
import joblib
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly

# %%
# %matplotlib inline

# %% [markdown]
# # 1. Business Understanding
#
# ## Problem Statement
# Diabetes is one of the most common chronic diseases worldwide and often develops slowly without obvious symptoms. As a result, many individuals remain unaware that they are at risk until complications begin to develop. Delayed detection can lead to serious health problems such as heart disease, kidney failure, nerve damage and vision loss
#
# While medical diagnosis requires laboratory tests and professional consultation, many people do not seek medical attention until symptoms become severe. Therefore, there is a need for an accessible screening tool that can help individuals recognise when they may be at higher risk of diabetes and encourage them to seek professional medical assessment earlier
#
# ## Goal
# The goal of this project is to develop a machine learning classification model that predicts whether an individual is likely to have diabetes based on their health indicators and medical history. The model will be deployed as a Streamlit web application for users to perform a quick self-assessment
#
# ## Business Objective
# The application is intended to function as a screening tool rather than a medical diagnosis. It helps users identify whether they may be at risk of diabetes and encourages those with a high-risk prediction to seek further medical assessment. The project also demonstrates how machine learning can support early disease detection in healthcare
#
# ## Success Criteria
# The project will compare multiple classification algorithms using Accuracy, Precision, Recall and F1-score. Recall is considered the most important evaluation metric because reducing False Negatives is more critical than reducing False Positives in a healthcare screening application. The selected model should achieve strong overall performance while identifying as many at risk individuals as possible while maintaining acceptable Precision to avoid excessive false alarms

# %% [markdown]
# # 2. Data Understanding

# %% [markdown]
# ## 2.1 Load dataset

# %%
# Read the diabetes prediction dataset into pandas DataFrame
df = pd.read_csv("diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# Dataset Size
# - Records: 100,000
# - Features: 9 input variables
# - Target Variable: diabetes

# %% [markdown]
# ## 2.2 Summary Statistics

# %%
# Understand the type of variable for each column (Check data types, Verify number of records, Identify categorical and numerical features)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  str
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  str
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 8.0 MB

# %% [markdown]
# ### My Observations
# - The dataset contains numerical, categorical and Binary indicator variables
# - Numerical features include age, bmi, HbA1c_level and blood_glucose_level
# - Categorical features include gender and smoking_history
# - Binary indicator features hypertension, heart_disease and diabetes

# %%
## Check for missing data
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# ### My Observations
# - No missing values detected from columns, currently no handling of missing data is required

# %%
## Describe data distribution
df.describe(include='all')
# Out:
#         gender            age  hypertension  heart_disease smoking_history  \
# count   100000  100000.000000  100000.00000  100000.000000          100000
# unique       3            NaN           NaN            NaN               6
# top     Female            NaN           NaN            NaN         No Info
# freq     58552            NaN           NaN            NaN           35816
# mean       NaN      41.885856       0.07485       0.039420             NaN
# std        NaN      22.516840       0.26315       0.194593             NaN
# min        NaN       0.080000       0.00000       0.000000             NaN
# 25%        NaN      24.000000       0.00000       0.000000             NaN
# 50%        NaN      43.000000       0.00000       0.000000             NaN
# 75%        NaN      60.000000       0.00000       0.000000             NaN
# max        NaN      80.000000       1.00000       1.000000             NaN
#
# ...

# %% [markdown]
# #### My Observations
# - HbA1c ranges from 3.5 to 9.0
# - Blood glucose ranges from 80 to 300
# - BMI ranges from 10.01	to 95.69
# - Age ranges from 0.08 to 80
# - Gender column has 3 unique variables
# - Smoking history has 6 unique variables
# #### My Assumption
# - All variables look medically reasonable

# %% [markdown]
# ## 2.3 Data Visualization

# %% [markdown]
# ### 2.3.1 Understanding distribution of data

# %% [markdown]
# ## Objective
# Before modelling, it is necessary to understand how the target variable and individual features are distributed. This helps identify class imbalance, skewness and potential outliers that may affect model training and metric selection

# %% [markdown]
# ### 2.3.1.1 Understanding distribution of target

# %%
# Plot distribution of target variable (Diabetes)
df['diabetes'].value_counts().plot(kind='bar')

plt.title("Distribution of Diabetes Outcome")
plt.xlabel("Diabetes (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### My Observation
# - Dataset is mainly comprised of people with no diabetes
#
# ### My Assumptions
# - Possible data imbalance, with a lot more non-diabetic than diabetic cases, this may cause the model to favour the majority class
# - recall and F1-score is needed to provide a more balanced assessment of model performance

# %% [markdown]
# ### 2.3.1.2 Understanding distribution of features

# %%
## Understanding distribution of features
# Plot histograms for all numerical features
df.hist(figsize=(10,10), bins=20)
plt.show()

# %% [markdown]
# ### My Observations
# - Age is distributed across a wide range, indicating the dataset includes individuals from various age groups.
# - BMI shows a right-skewed distribution, with most individuals having lower to moderate BMI values and fewer individuals with very high BMI values.

# %%
# Plot distribution of smoking_history
df['smoking_history'].value_counts().plot(kind='bar')

plt.title("Distribution of Smoking History")
plt.xlabel("Smoking History")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
df["smoking_history"].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %% [markdown]
# ### My Observations
# - "No Info" is the largest smoking category
# - Categories "Former", "not current" and "Ever" may overlap, these categories all represent people with previous smoking exposure but differ mainly in duration
# - "No Info" represents missing or undisclosed information rather than smoking behaviour
# ### My Assumptions
# - Smoking categories may be consolidated to reduce redundancy
# - "No Info" could represent individuals that may have chosen not to disclose their smoking history so they cannot automatically be interpreted as "Never Smoked"

# %%
# Plot distribution of target variable (Gender)
df['gender'].value_counts().plot(kind='bar')

plt.title("Distribution of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
# Check the count of each gender in the dataset
df["gender"].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %% [markdown]
# ### My Observation
# - Female and Male comprise almost all of the rows
# - "Other" contains only a very small number of records
#
# ### My Assumptions
# - Since the "Other" category has very limited samples, the model may not have enough examples to learn reliable patterns between this group and diabetes risk
# - Including a category with insufficient data may introduce noise and result in unreliable predictions for individuals belonging to this category

# %%
# Plot boxplot for all features to check for outliers
df.boxplot(rot=45, figsize=(12,6)) ## rot: rotation of label
plt.show()

# %% [markdown]
# ### My Observation
# - The boxplot display several outliers for BMI and Blood Glucose Level
# ### My Assumptions
# - The outliers identified are still medically possible and can represent people with obesity, high blood sugar or malnutrition
# - (Bmi of 10.01 to 95.69 & Blood Glucose Level of 80 to 300)
# - Removing these values could reduce the chance of identifying people with these conditions, so i choose to keep these outliers

# %% [markdown]
# ### 2.3.2 Understanding relationship between variables

# %%
# Select numeric columns (hint: float/int types)
col_numeric = df.select_dtypes(include=['float', 'int']).columns

# Compute correlation matrix (relationship between numeric variables)
df_corr = df[col_numeric].corr()

df_corr
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.101354             0.110672  0.258008
# hypertension            0.080939             0.084429  0.197823
# heart_disease           0.067589             0.070066  0.171727
# bmi                     0.082997             0.091261  0.214357
# HbA1c_level             1.000000             0.166733  0.400660
# ...

# %%
# Visualize correlation matrix using heatmap
sns.heatmap(df_corr, cmap='RdYlGn')
plt.show()

# %% [markdown]
# ### My Observations
# - HbA1c and blood glucose show the strongest correlation with diabetes
# - Other variables show weaker correlations
# - (Correlation to Diabetes) Blood Glucose > HbA1c Level > age > bmi > hypertension > heart disease
# ### My Assumptions
# - All features have a part to play in predicting diabetes but Blood Glucose and HbA1c Level are the main factors

# %%
## Understanding relationship between variables and diabetes outcome
## Plot pairplot
sns.pairplot(df, hue='diabetes')
plt.show()

# %% [markdown]
# ### My Observations
# - Diabetic individuals are generally seen with higher blood glucose and HbA1c levels
# - Older individuals seem to have a higher appearance of diabetes cases
# - More diabetes cases seem to be observed more with individuals of higher BMIs
# - Hypertension and Heart Disease shows some separation between the two classes (Individuals observed with the condition have higher chance of having diabetes)
# - Most variables show overlap between diabetic and non-diabetic patients, suggesting multiple features are required for accurate prediction
# ### My Assumptions
# - Blood glucose and HbA1c are likely the most important predictors of diabetes
# - A single feature cannot perfectly distinguish diabetic patients, supporting the use of machine learning models combining multiple variables

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# ## 3.1 Data Cleaning

# %%
# Check duplicate rows
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 3854

# %% [markdown]
# ### My Observation
# - The dataset contains rows of duplicate records (3854)
#
# ### My Analysis
# - Duplicate records are not necessarily data entry errors. In a medical dataset different individuals can possibly have identical health profiles, so duplicate rows may represent real observations rather than redundant data
# - To verify this, duplicate records were removed and the model was retrained (V2) and Model performance decreased across all evaluation metrics, including Recall
# - This suggests that the duplicate records reinforce common health patterns and help the model learn more reliable decision rules. Therefore, the duplicate rows were retained in the final dataset

# %%
# Remove rows with gender "Other" from the dataset
df = df[df["gender"] != "Other"]
df["gender"].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Name: count, dtype: int64

# %% [markdown]
# ### Reason for Removing "Other" Category
# - The "Other" gender category was removed before model training as it has significantly fewer samples (18) compared to Male (41430) and Female (58552)
# - Although keeping all categories improves representation, the model requires sufficient examples from each category to learn meaningful patterns and with only a limited number of records the model may not generalise patterns accurately and could introduce additional noise into the feature representation
# - Removing this category reduces the complexity of the feature space and allows the model to focus on patterns supported by sufficient training examples

# %%
# Merge smoking history categories

df["smoking_history"] = df["smoking_history"].replace({
    "never": "Non-Smoker",
    "former": "Past Smoker",
    "not current": "Past Smoker",
    "ever": "Past Smoker",
    "current": "Current Smoker",
    "No Info": "Prefer Not to Say"
})

df["smoking_history"].value_counts()
# Out:
# smoking_history
# Prefer Not to Say    35810
# Non-Smoker           35092
# Past Smoker          19794
# Current Smoker        9286
# Name: count, dtype: int64

# %% [markdown]
# #### 1. Reason for Grouping Smoking Categories
# - The original dataset contains six smoking history categories, including "former", "not current" and "ever", which all describe individuals with previous smoking history
# - After one-hot encoding, each category becomes a separate feature, multiple categories with similar meanings increases feature complexity without providing additional predictive information
# - Increasing feature complexity can make it more difficult for the model to identify meaningful patterns because similar information is represented by multiple features instead of one
# #### Changes
# - Therefore "former", "not current" and "ever" were merged into "Past Smoker" to reduce redundancy while still getting the important information that the individual has smoked before
# - The "No Info" category was renamed to "Prefer Not to Say" instead of "Non-Smoker" because missing information is different from no smoking history
# - This preserves all observations while creating categories that are easier for users to understand when using the application

# %% [markdown]
# #### 2. Evaluation of Feature Engineering (Smoking History Consolidation)
# #### My Observation
# - Decision Tree continued to achieve the highest Recall (0.7449) among the three models
# - Consolidating the smoking history categories produced a small improvement across all evaluation metrics compared with V1
# - (Accuracy: 0.9531 to 0.9538, Precision: 0.7150 to 0.7182, Recall: 0.7393 to 0.7449, F1-score: 0.7270 to 0.7313)
# - The Decision Tree also reduced False Negatives from 660 to 646 while increasing True Positives from 1,872 to 1,886
# #### My Analysis
# - Consolidating the smoking history categories reduced redundant feature categories while preserving meaningful smoking history information
# - After one-hot encoding, fewer overlapping categories resulted in a simpler feature representation for the model to learn from
# - This contributed to small but consistent improvements in Accuracy, Precision, Recall and F1-score, while also reducing the number of diabetic individuals incorrectly classified as healthy
# - The results suggest that the original smoking categories contained overlapping information rather than distinct predictive patterns
# #### Business Impact
# - Since Recall is the most important evaluation metric for this project, the improvement from 0.7393 to 0.7449 means more individuals at risk of diabetes are correctly identified
# - The reduction in False Negatives (660 to 646) further supports this improvement by showing that fewer diabetic individuals were missed by the model
# - In addition, simplifying the smoking history options into Non-Smoker, Past Smoker, Current Smoker and Prefer Not to Say makes the application easier for users to understand while maintaining predictive performance
# - Therefore, this feature engineering step was accepted and retained in the final model

# %%
## One-Hot Encoding
## Convert categorical variables (gender and smoking_history) into binary columns so machine learning algorithms can process
df = pd.get_dummies(df, columns=['gender','smoking_history'], drop_first=True
)

## Define Features (X) and Target (y)
col_y = "diabetes"
X = df.drop(columns=[col_y])
y = df[col_y]

df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  gender_Male  smoking_history_Non-Smoker  \
# 0                      140         0        False                        True
# ...

# %% [markdown]
# ## Rejected Feature Engineering
# ### Age and BMI Binning
#
# #### My Observation
# - Age and BMI were grouped into categorical ranges to investigate whether broader categories could improve model performance.
# #### My Analysis
# - Binning age and BMI reduced the Decision Tree's Accuracy from 0.9538 to 0.9530, Precision from 0.7182 to 0.7146, Recall from 0.7449 to 0.7385, and F1-score from 0.7313 to 0.7264 compared with using the original continuous values.
# - This indicates that the exact numerical values provide more predictive information than grouped categories. Therefore, age and BMI were retained as continuous variables in the final model.

# %% [markdown]
# ## 3.2 Train-Test Split

# %%
## Split data into train set and test set
## Separating the data prevents the model from evaluating on data it has seen, providing realistic estimates of model performance 
from sklearn.model_selection import train_test_split

# Split the data (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2026)

# %% [markdown]
# # 4. Modelling

# %% [markdown]
# ### 4.1 Train Model

# %%
# Model training
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Initialize model
gbt = GradientBoostingClassifier(random_state=2026)
rf = RandomForestClassifier(random_state=2026)
dt = DecisionTreeClassifier(random_state=2026)


# Train model on training data
dt.fit(X_train, y_train)
gbt.fit(X_train, y_train)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=2026)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# ### Evaluation Criteria
#
# The objective of this project is to identify individuals who may have diabetes based on their health indicators
#
# As a medical indicator, failing to identify a diabetic patient (False Negative) is generally more serious than incorrectly flagging a healthy individual (False Positive).
# Therefore, Recall is an important evaluation metric because it measures how many actual diabetic patients are correctly identified.
#
# However, relying only on Recall may produce many False Positives. Therefore, Precision, F1-score and Accuracy are also evaluated to ensure the model provides a balanced overall performance.

# %%
# Model evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Predict on test set
y_pred = dt.predict(X_test)
y_pred_gbt = gbt.predict(X_test)
y_pred_rf = rf.predict(X_test)

# Evaluate model performance using classification metrics
for name, preds in [("Decision Tree", y_pred), ("Gradient Boosting", y_pred_gbt), ("Random Forest", y_pred_rf)]:
    print(f"--- {name} ---")
    print(f"  Accuracy:  {accuracy_score(y_test, preds):.4f}")
    print(f"  Precision: {precision_score(y_test, preds):.4f}")
    print(f"  Recall:    {recall_score(y_test, preds):.4f}")
    print(f"  F1 Score:  {f1_score(y_test, preds):.4f}")
    print()
# Out:
# --- Decision Tree ---
#   Accuracy:  0.9538
#   Precision: 0.7182
#   Recall:    0.7449
#   F1 Score:  0.7313
#
# --- Gradient Boosting ---
#   Accuracy:  0.9728
#   Precision: 0.9831
#   Recall:    0.6892
#   F1 Score:  0.8103
#
# --- Random Forest ---
#   Accuracy:  0.9705
#   Precision: 0.9392
#   Recall:    0.6951
#   F1 Score:  0.7989

# %%
from sklearn.metrics import classification_report
print("Decision Tree")
print(classification_report(y_test, y_pred))

print("Gradient Boosting")
print(classification_report(y_test, y_pred_gbt))

print("Random Forest")
print(classification_report(y_test, y_pred_rf))
# Out:
# Decision Tree
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97     27463
#            1       0.72      0.74      0.73      2532
#
#     accuracy                           0.95     29995
#    macro avg       0.85      0.86      0.85     29995
# weighted avg       0.95      0.95      0.95     29995
#
# Gradient Boosting
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     27463
#            1       0.98      0.69      0.81      2532
#
#     accuracy                           0.97     29995
#    macro avg       0.98      0.84      0.90     29995
# weighted avg       0.97      0.97      0.97     29995
#
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     27463
#            1       0.94      0.70      0.80      2532
#
#     accuracy                           0.97     29995
# ...

# %%
comparison_df = pd.DataFrame({
    "Model": ["Decision Tree", "Random Forest", "Gradient Boosting"],
    "Accuracy": [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_gbt)
    ],
    "Precision": [
        precision_score(y_test, y_pred),
        precision_score(y_test, y_pred_rf),
        precision_score(y_test, y_pred_gbt)
    ],
    "Recall": [
        recall_score(y_test, y_pred),
        recall_score(y_test, y_pred_rf),
        recall_score(y_test, y_pred_gbt)
    ],
    "F1 Score": [
        f1_score(y_test, y_pred),
        f1_score(y_test, y_pred_rf),
        f1_score(y_test, y_pred_gbt)
    ]
})

comparison_df.set_index("Model").plot(
    kind="bar",
    figsize=(10,6),
    width=0.8
)

plt.title("Performance Comparison of Classification Models")
plt.xlabel("Model")
plt.ylabel("Score")
plt.ylim(0.65, 1.00)
plt.xticks(rotation=0)
plt.legend(loc="lower right")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.title("Decision Tree")
plt.show()

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_gbt)
plt.title("Gradient Boosting")
plt.show()

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf)
plt.title("Random Forest")
plt.show()

# %% [markdown]
# ## Model Comparison and Final Model Selection
#
# ## 1. Confusion Matrix
# #### 1.1 My Observations
# - Decision Tree correctly identified the highest number of diabetic individuals (1,886 True Positives) and produced the fewest False Negatives (646), but also generated the highest number of False Positives (740)
# - Gradient Boosting achieved the highest number of True Negatives (27,433) and the fewest False Positives (30), but missed the most diabetic individuals with 787 False Negatives
# - Random Forest provided balanced results with 1,760 True Positives, 772 False Negatives and 114 False Positives, being in between the Decision Tree and Gradient Boosting
# #### 1.2 My Analysis
# - The Decision Tree is the most effective model for identifying diabetic individuals because it produces the fewest False Negatives, although this comes at the expense of more False Positives
# - Gradient Boosting is the most conservative model, correctly identifying healthy individuals while missing more diabetic patients
# - Random Forest provides a balance between sensitivity and precision but does not outperform the Decision Tree in identifying diabetic patients
# #### 1.3 Business Impact
# - In a diabetes screening application, False Negatives are more critical than False Positives because an undetected diabetic individual may delay seeking medical assessment and treatment
# - The Decision Tree reduced False Negatives from 660 (V1) to 646 (V3) after consolidating the smoking history categories, meaning more at-risk individuals were successfully identified
# - Therefore, Confusion Matrix supports the Decision Tree as the preferred model because it best supports the project objective of early diabetes risk screening while also showing that the accepted feature engineering improvement produced a measurable reduction in missed diabetic cases
#
# ## 2. Classification metrics
# #### 2.1 Quantitative Comparison
# - Decision Tree achieved the highest Recall (0.7449), correctly identifying the largest number of diabetic individuals among the three models. However, it had the lowest Precision (0.7182), resulting in more False Positives
# - Gradient Boosting achieved the highest Accuracy (0.9728), Precision (0.9831) and F1-score (0.8103), but had the lowest Recall (0.6892), meaning it missed more diabetic patients
# - Random Forest produced balanced performance across all evaluation metrics but did not outperform the Decision Tree in Recall or Gradient Boosting in Accuracy, Precision and F1-score
# - Overall, each model shows a different pros and cons between identifying diabetic patients and minimising incorrect positive predictions
# - Decision Tree required the shortest training time among the three models because it builds a single tree, making it computationally efficient. Faster training is beneficial when models need to be retrained regularly as new healthcare data becomes available, reducing computational resources and deployment time
# ##### 2.2 Qualitative Comparison
# - Decision Tree is easy to interpret because its decision rules can be visualised and explained, making it suitable for healthcare screening applications where prediction transparency is important
# - Random Forest and Gradient Boosting are ensemble models that generally provide stronger predictive performance but are less interpretable, making it more difficult to explain individual predictions
# - Since this application is designed as a screening tool rather than a diagnostic system, identifying more at-risk individuals is prioritised over reducing false alarms
# #### 2.3 Model Selection
# - Although the Decision Tree has a lower Precision (0.7182) than the ensemble models, it still correctly classifies the majority of positive predictions while achieving the highest Recall (0.7449). This means the model identifies more individuals who may have diabetes, reducing the number of missed diabetic cases
# - For an early diabetes screening application, a higher number of False Positives is considered more acceptable than a higher number of False Negatives, as individuals identified as high risk can undergo further medical assessment to confirm the diagnosis. Therefore, the Decision Tree was selected as the final model because it best satisfies the project's objective of maximising early detection while remaining simple to interpret and deploy

# %% [markdown]
# ## 6. Further feature engineering / feature selection

# %% [markdown]
# ### Iterative model development

# %% [markdown]
# ### Objective
#
# To determine whether removing low-importance features could simplify the model without reducing prediction performance.

# %%
## Retrieve feature importance
df_dt_feat_impt = pd.DataFrame({
                                 'Feature': dt.feature_names_in_,
                                 'Importance': dt.feature_importances_
                            })
## Obtain feature importance from OHE feature names
df_dt_feat_impt['Feature'] = df_dt_feat_impt['Feature'].str.rsplit('_', n=1).str[0] ## Extract original feature name from one-hot encoded feature
df_dt_feat_impt = df_dt_feat_impt.groupby('Feature')['Importance'].sum().reset_index()

## Calculate cumulative importance
df_dt_feat_impt['Cumulative importance'] = df_dt_feat_impt['Importance'].cumsum()

df_dt_feat_impt
# Out:
#            Feature  Importance  Cumulative importance
# 0            HbA1c    0.491695               0.491695
# 1              age    0.067438               0.559133
# 2    blood_glucose    0.270338               0.829472
# 3              bmi    0.123289               0.952760
# 4           gender    0.013780               0.966540
# 5            heart    0.005224               0.971764
# 6     hypertension    0.004772               0.976536
# 7  smoking_history    0.023464               1.000000

# %%
## Retrieve feature importance
df_dt_feat_impt = pd.DataFrame({
                               'Feature': dt.feature_names_in_,
                               'Importance': dt.feature_importances_
                             })


## Obtain original feature from OHE feature names
df_dt_feat_impt['Feature'] = df_dt_feat_impt['Feature'].str.rsplit('_', n=1).str[0]
df_dt_feat_impt = df_dt_feat_impt.groupby('Feature')['Importance'].sum().sort_values(ascending=False).reset_index()
 
## Calculate cumulative importance
df_dt_feat_impt['Cumulative importance'] = df_dt_feat_impt['Importance'].cumsum()
 
df_dt_feat_impt.sort_values(
    by="Importance",
    ascending=False
)
 
## Plot feature importance and cumulative importance
fig, ax1 = plt.subplots(figsize=(10, 6))
 
# Bar chart for feature importance
ax1.bar(df_dt_feat_impt['Feature'], df_dt_feat_impt['Importance'], color='skyblue')
ax1.set_xlabel('Features')
ax1.set_ylabel('Feature Importance', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
plt.xticks(rotation=45, ha="right")
 
# Line chart for cumulative importance
ax2 = ax1.twinx()
ax2.plot(df_dt_feat_impt['Feature'], df_dt_feat_impt['Cumulative importance'], color='red', marker='o')
ax2.set_ylabel('Cumulative Importance', color='red')
ax2.tick_params(axis='y', labelcolor='red')
 
plt.title('Feature Importance and Cumulative Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### My Observations
# - HbA1c level and blood glucose level have the highest feature importance, indicating they contribute most to predicting diabetes
# - BMI and age also contribute to the prediction, but to a lesser extent
# - Hypertension, heart disease, gender and smoking history have comparatively low feature importance
# ### My Analysis
# - Feature importance suggests that hypertension, heart disease, gender and smoking history contribute less to the model than the other predictors
# - Features with lower importance can be selected for further investigation to determine whether removing them could simplify the model without reducing predictive performance
# - Since feature importance measures only the individual contribution of each feature, further testing is required before deciding whether any feature should be removed

# %%
# Feature selection remove Hypertension (Test)

# Remove hypertension feature
X_no_hypertension = X.drop(columns=["hypertension"])

# Split the reduced dataset
X_train_h, X_test_h, y_train_h, y_test_h = train_test_split(
    X_no_hypertension,
    y,
    test_size=0.3,
    random_state=2026
)

# Train Decision Tree
dt_no_h = DecisionTreeClassifier(random_state=2026)
dt_no_h.fit(X_train_h, y_train_h)

# Predict
y_pred_no_h = dt_no_h.predict(X_test_h)

# Display evaluation metrics
print("Decision Tree (Without Hypertension)")
print(f"Accuracy : {accuracy_score(y_test_h, y_pred_no_h):.4f}")
print(f"Precision: {precision_score(y_test_h, y_pred_no_h):.4f}")
print(f"Recall   : {recall_score(y_test_h, y_pred_no_h):.4f}")
print(f"F1 Score : {f1_score(y_test_h, y_pred_no_h):.4f}")
# Out:
# Decision Tree (Without Hypertension)
# Accuracy : 0.9522
# Precision: 0.7080
# Recall   : 0.7374
# F1 Score : 0.7224

# %%
# Feature selection remove Heart Disease (Test)

# Remove heart disease feature
X_no_hd = X.drop(columns=["heart_disease"])

# Split the reduced dataset
X_train_hd, X_test_hd, y_train_hd, y_test_hd = train_test_split(
    X_no_hd,
    y,
    test_size=0.3,
    random_state=2026
)

# Train Decision Tree
dt_no_hd = DecisionTreeClassifier(random_state=2026)
dt_no_hd.fit(X_train_hd, y_train_hd)

# Predict
y_pred_no_hd = dt_no_hd.predict(X_test_hd)

# Display evaluation metrics
print("Decision Tree (Without Heart Disease)")
print(f"Accuracy : {accuracy_score(y_test_hd, y_pred_no_hd):.4f}")
print(f"Precision: {precision_score(y_test_hd, y_pred_no_hd):.4f}")
print(f"Recall   : {recall_score(y_test_hd, y_pred_no_hd):.4f}")
print(f"F1 Score : {f1_score(y_test_hd, y_pred_no_hd):.4f}")
# Out:
# Decision Tree (Without Heart Disease)
# Accuracy : 0.9525
# Precision: 0.7093
# Recall   : 0.7409
# F1 Score : 0.7247

# %%
# Compare Feature Selection Tests

comparison_fs = pd.DataFrame({

    "Model Version": [
        "Current Model",
        "Without Hypertension",
        "Without Heart Disease"
    ],

    "Accuracy": [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test_h, y_pred_no_h),
        accuracy_score(y_test_hd, y_pred_no_hd)
    ],

    "Precision": [
        precision_score(y_test, y_pred),
        precision_score(y_test_h, y_pred_no_h),
        precision_score(y_test_hd, y_pred_no_hd)
    ],

    "Recall": [
        recall_score(y_test, y_pred),
        recall_score(y_test_h, y_pred_no_h),
        recall_score(y_test_hd, y_pred_no_hd)
    ],

    "F1 Score": [
        f1_score(y_test, y_pred),
        f1_score(y_test_h, y_pred_no_h),
        f1_score(y_test_hd, y_pred_no_hd)
    ]

})

comparison_fs
# Out:
#            Model Version  Accuracy  Precision    Recall  F1 Score
# 0          Current Model  0.953792   0.718203  0.744866  0.731291
# 1   Without Hypertension  0.952159   0.708002  0.737362  0.722383
# 2  Without Heart Disease  0.952492   0.709263  0.740916  0.724744

# %% [markdown]
# ### My Observations
# - Removing hypertension reduced Accuracy from 0.9538 to 0.9522, Recall from 0.7449 to 0.7374, and F1-score from 0.7313 to 0.7224
# - Removing heart disease also reduced model performance, with Accuracy decreasing to 0.9525, Recall to 0.7409, and F1-score to 0.7247
# - The original model consistently achieved the highest Recall and F1-score among the three versions
# ### My Analysis
# - Although hypertension and heart disease had relatively low feature importance, removing either feature reduced the models ability to correctly identify diabetic individuals
# - This suggests that these variables still provide complementary information when combined with the other health indicators, even if they contribute less individually
# - The feature importance results therefore should not be interpreted as a reason to automatically remove the lower ranked variables
# ### Business Impact
# - Since the objective of this project is to maximise Recall for early diabetes screening, even small reductions in Recall mean more diabetic individuals are incorrectly classified as healthy.
# - Therefore, both hypertension and heart disease were retained in the final model because removing them reduced prediction performance without providing any practical benefit

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Objective
#
# To determine whether optimising the Decision Tree hyperparameters could improve model performance while maintaining strong Recall for diabetes screening.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

# Base model
dt = DecisionTreeClassifier(random_state=2026)

# Hyperparameter search space
param_dist_dt = {
    "max_depth": [10, 15, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

rs_dt = RandomizedSearchCV(
    estimator=dt,
    param_distributions=param_dist_dt,
    n_iter=10,
    cv=5,
    scoring="recall",
    random_state=2026,
    n_jobs=-1
)

rs_dt.fit(X_train, y_train)

best_rs_dt = rs_dt.best_estimator_

print("Best Parameters:")
print(rs_dt.best_params_)

y_pred_dt_tuned = best_rs_dt.predict(X_test)
# Out:
# Best Parameters:
# {'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': None}

# %%
results = []

models = [
    ("Decision Tree", y_pred_dt_tuned)
]

for name, pred in models:

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, pred),
        "Precision": precision_score(y_test, pred),
        "Recall": recall_score(y_test, pred),
        "F1 Score": f1_score(y_test, pred)
    })

results_df = pd.DataFrame(results)

results_df
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score
# 0  Decision Tree   0.96076   0.793163  0.723934  0.756969

# %%
comparison_tuning = pd.DataFrame({

    "Version": ["Baseline", "Tuned"],

    "Accuracy": [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test, y_pred_dt_tuned)
    ],

    "Precision": [
        precision_score(y_test, y_pred),
        precision_score(y_test, y_pred_dt_tuned)
    ],

    "Recall": [
        recall_score(y_test, y_pred),
        recall_score(y_test, y_pred_dt_tuned)
    ],

    "F1 Score": [
        f1_score(y_test, y_pred),
        f1_score(y_test, y_pred_dt_tuned)
    ]
})

comparison_tuning
# Out:
#     Version  Accuracy  Precision    Recall  F1 Score
# 0  Baseline  0.953792   0.718203  0.744866  0.731291
# 1     Tuned  0.960760   0.793163  0.723934  0.756969

# %% [markdown]
# ### My Observations
# - Hyperparameter tuning increased Accuracy from 0.9538 to 0.9608
# - Precision improved from 0.7182 to 0.7932, indicating that fewer healthy individuals were incorrectly classified as diabetic
# - F1-score also increased from 0.7313 to 0.7570, showing a better balance between Precision and Recall
# - However, Recall decreased from 0.7449 to 0.7239, meaning fewer diabetic individuals were correctly identified
# ### My Analysis
# - Increasing min_samples_leaf from 1 to 2 reduced overfitting by preventing the Decision Tree from creating decision rules based on very small groups of samples
# - This produced a more generalised model that made fewer incorrect positive predictions, resulting in higher Precision and Accuracy
# - However, the more conservative decision boundaries also caused some diabetic individuals to be classified as non-diabetic, leading to a reduction in Recall
# - The results demonstrate the trade-off between identifying more diabetic individuals and reducing False Positives when tuning Decision Tree hyperparameters
# ### Business Impact
# - Although the tuned model achieved better Accuracy, Precision and F1-score, the reduction in Recall means more diabetic individuals would be missed during screening
# - Since the primary objective of this project is early diabetes risk detection, reducing False Negatives is considered more important than reducing False Positives
# - Therefore, the baseline Decision Tree was retained as the final model because it achieved the highest Recall and best supports the project's objective of identifying as many at-risk individuals as possible

# %% [markdown]
# ## 7. Save Model

# %%
## Save trained model
#import joblib
joblib.dump(dt,"decision_tree_model.pkl")
## Load trained model
model = joblib.load("decision_tree_model.pkl")

# %% [markdown]
# # Development Log
#
# ## Version Summary V1 (Base)
#
# Changes:
# - Removed the underrepresented "Other" gender category
# - Applied one-hot encoding to categorical variables
# - Trained and evaluated Decision Tree Random Forest and Gradient Boosting models
#
# Results:
# - Accuracy:  0.9531
# - Precision: 0.7150
# - Recall:    0.7393
# - F1 Score:  0.7270
#
# - Decision Tree True Negatives (26717), False Positives (747), False Negatives (660), True Positives (1872)
#
# Decision:
# - Although Gradient Boosting achieved the highest overall accuracy, F1-score and Precision. Missing diabetic patients has greater medical consequences than incorrectly flagging healthy individuals. Hence, the Decision Tree was selected for the baseline as it achieved the highest Recall (0.7393) and least False Negatives (660)

# %% [markdown]
# ## Version Summary V2
#
# Changes:
# - Removed duplicate records from the dataset before model training to investigate whether duplicate observations were affecting model performance
#
# Results:
# - Accuracy:  0.9472
# - Precision: 0.6891
# - Recall:    0.7349
# - F1 Score:  0.7113
#
# - Decision Tree True Negatives (25438), False Positives (847), False Negatives (677), True Positives (1877)
#
# Decision:
# - Removing duplicate records resulted in lower performance across all evaluation metrics, including Recall. This suggests that the duplicate rows may contain meaningful observations rather than redundant data. Therefore, this change is rejected and the previous version will be retained as the current best model

# %% [markdown]
# ## Version Summary V3
#
# Changes:
# - Consolidated smoking history categories
# - Merged "former", "not current" and "ever" into "Past Smoker"
# - Renamed "No Info" to "Prefer Not to Say"
# - Renamed "current" to "Current Smoker"
# - Renamed "never" to "Non-Smoker"
#
# Results:
# - Accuracy:  0.9538
# - Precision: 0.7182
# - Recall:    0.7449
# - F1 Score:  0.7313
#
# - Decision Tree True Negatives (26723), False Positives (740), False Negatives (646), True Positives (1886)
#
# Decision:
# - The consolidated smoking history categories produced small but consistent improvements across all evaluation metrics compared with V1. Specifically, in Decision Tree Recall increased from 0.7393 to 0.7449 while False Negatives decreased from 660 to 646. Simplifying the smoking categories also reduces feature complexity, makes the model easier to interpret and better reflects realistic user responses. Therefore, this change is accepted and becomes the new current best model

# %% [markdown]
# ## Version Summary V4
#
# Changes
# - Tested Feature engineering the Age and Bmi categories
#
# Decision
# - Rejected because it reduced the Accuracy, Precision, Recall and F1-Score
# - Binning age and BMI into categories likely removed fine grained numeric information the Decision Tree was previously using to make finer splits, reducing its ability to separate borderline cases

# %% [markdown]
# ## Version Summary V5
#
# Changes
# - Attempted to use class weighting to address imbalance in the dataset
#
# Decision
# - Rejected because it Reduced the Accuracy, Precision, Recall and F1-Score
# - Applying class_weight="balanced" over-corrected for the class imbalance, causing the model to over-predict the diabetic class. This increased the number of False Positives faster than it reduced False Negatives, lowering Precision and F1-score without a net improvement in Recall

# %% [markdown]
# ## Version Summary V6
#
# Changes
# - Investigated feature importance
# - Tested removing hypertension
# - Tested removing heart disease
#
# Decision
# - Rejected because removing either feature reduced Recall and overall model performance

# %% [markdown]
# ## Version Summary V7
#
# Changes
# - Applied RandomizedSearchCV hyperparameter tuning
# - Optimised max_depth, min_samples_split and min_samples_leaf
#
# Results
# Accuracy : 0.9608
# Precision: 0.7932
# Recall   : 0.7239
# F1 Score : 0.7570
#
# Best Parameters
# - max_depth = None
# - min_samples_split = 2
# - min_samples_leaf = 2
#
# Decision
# Although tuning improved Accuracy, Precision and F1-score, Recall decreased from 0.7449 to 0.7239. Since this project prioritises identifying as many diabetic individuals as possible, the tuned model was rejected and Version 3 remained the final production model.
